# %% [markdown]
# # Detección de Covid-19 mediante Machine learning

# %% [markdown]
# El avance tecnológico ha tenido un impacto profundo en todos los aspectos de la vida, incluyendo el ámbito médico. La inteligencia artificial, en particular, ha demostrado ser prometedora en la atención médica mediante el análisis y procesamiento de datos para la toma de decisiones. La detección temprana de enfermedades potencialmente mortales es crucial para prevenir su propagación y desarrollo. COVID-19, una enfermedad extremadamente contagiosa, ha causado una pandemia global que requiere una intervención rápida. La necesidad de un sistema eficaz para detectar el virus es evidente dada su rápida propagación. Con el aumento del uso de la tecnología, ahora tenemos acceso a una gran cantidad de datos sobre COVID-19 que pueden proporcionar información valiosa sobre el virus. En este proyecto, comparamos la precisión de varios algoritmos de aprendizaje automático para la predicción de COVID-19, y seleccionamos el algoritmo más preciso para el modelo final de prueba.

# %% [markdown]
# ## Diccionario de Datos
#
# ### Breathing Problem
#
# Descripción: Indica si el individuo tiene problemas respiratorios.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 3620
# No: 1814
#
# ### Fever
#
# Descripción: Indica si el individuo tiene fiebre.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 4273
# No: 1161
#
# ### Dry Cough
#
# Descripción: Indica si el individuo tiene tos seca.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 4307
# No: 1127
#
# ### Sore throat
#
# Descripción: Indica si el individuo tiene dolor de garganta.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 3953
# No: 1481
#
# ### Running Nose
#
# Descripción: Indica si el individuo tiene secreción nasal.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2952
# No: 2482
#
# ### Asthma
#
# Descripción: Indica si el individuo tiene asma.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2514
# No: 2920
#
# ### Chronic Lung Disease
#
# Descripción: Indica si el individuo tiene una enfermedad pulmonar crónica.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2565
# No: 2869
#
# ### Headache
#
# Descripción: Indica si el individuo tiene dolor de cabeza.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2736
# No: 2698
#
# ### Heart Disease
#
# Descripción: Indica si el individuo tiene una enfermedad cardíaca.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2523
# No: 2911
#
# ### Diabetes
#
# Descripción: Indica si el individuo tiene diabetes.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2588
# No: 2846
#
# ### Hyper Tension
#
# Descripción: Indica si el individuo tiene hipertensión.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2663
# No: 2771
#
# ### Fatigue
#
# Descripción: Indica si el individuo tiene fatiga.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2821
# No: 2613
#
# ### Gastrointestinal
#
# Descripción: Indica si el individuo tiene síntomas gastrointestinales.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2551
# No: 2883
#
# ### Abroad travel
#
# Descripción: Indica si el individuo ha viajado al extranjero.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2451
# No: 2983
#
# ### Contact with COVID Patient
#
# Descripción: Indica si el individuo ha estado en contacto con un paciente con COVID-19.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2726
# No: 2708
#
# ### Attended Large Gathering
#
# Descripción: Indica si el individuo ha asistido a una gran reunión.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2510
# No: 2924
#
# ### Visited Public Exposed Places
#
# Descripción: Indica si el individuo ha visitado lugares públicos expuestos.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2820
# No: 2614
#
# ### Family working in Public Exposed Places
#
# Descripción: Indica si algún miembro de la familia del individuo trabaja en lugares públicos expuestos.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 2262
# No: 3172
#
# ### Wearing Masks
#
# Descripción: Indica si el individuo usa mascarillas.
# Tipo: Categórico (Sí/No)
# Valores Únicos: No
# Frecuencia:
# No: 5434
#
# ### Sanitization from Market
#
# Descripción: Indica si el individuo se ha desinfectado al regresar del mercado.
# Tipo: Categórico (Sí/No)
# Valores Únicos: No
# Frecuencia:
# No: 5434
#
# ### COVID-19
#
# Descripción: Indica si el individuo ha sido diagnosticado con COVID-19.
# Tipo: Categórico (Sí/No)
# Valores Únicos: Sí, No
# Frecuencia:
# Sí: 4383
# No: 1051

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report,confusion_matrix, roc_auc_score, mean_squared_error,r2_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
covid_data = pd.read_csv("Covid Dataset.csv")
covid_data
# Out:
#      Breathing Problem Fever Dry Cough Sore throat Running Nose Asthma  \
# 0                  Yes   Yes       Yes         Yes          Yes     No
# 1                  Yes   Yes       Yes         Yes           No    Yes
# 2                  Yes   Yes       Yes         Yes          Yes    Yes
# 3                  Yes   Yes       Yes          No           No    Yes
# 4                  Yes   Yes       Yes         Yes          Yes     No
# ...                ...   ...       ...         ...          ...    ...
# 5429               Yes   Yes        No         Yes          Yes    Yes
# 5430               Yes   Yes       Yes          No          Yes    Yes
# 5431               Yes   Yes       Yes          No           No     No
# 5432               Yes   Yes       Yes          No          Yes     No
# 5433               Yes   Yes       Yes          No          Yes    Yes
#
#      Chronic Lung Disease Headache Heart Disease Diabetes  ... Fatigue   \
# ...

# %%
covid_data.shape
# Out:
# (5434, 21)

# %% [markdown]
# existe 5434 filas y 21 colummnas

# %%
covid_data.columns
# Out:
# Index(['Breathing Problem', 'Fever', 'Dry Cough', 'Sore throat',
#        'Running Nose', 'Asthma', 'Chronic Lung Disease', 'Headache',
#        'Heart Disease', 'Diabetes', 'Hyper Tension', 'Fatigue ',
#        'Gastrointestinal ', 'Abroad travel', 'Contact with COVID Patient',
#        'Attended Large Gathering', 'Visited Public Exposed Places',
#        'Family working in Public Exposed Places', 'Wearing Masks',
#        'Sanitization from Market', 'COVID-19'],
#       dtype='object')

# %% [markdown]
# muestra todas los nombres de las variables

# %%
covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5434 entries, 0 to 5433
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Breathing Problem                        5434 non-null   object
#  1   Fever                                    5434 non-null   object
#  2   Dry Cough                                5434 non-null   object
#  3   Sore throat                              5434 non-null   object
#  4   Running Nose                             5434 non-null   object
#  5   Asthma                                   5434 non-null   object
#  6   Chronic Lung Disease                     5434 non-null   object
#  7   Headache                                 5434 non-null   object
#  8   Heart Disease                            5434 non-null   object
#  9   Diabetes                                 5434 non-null   object
# ...

# %%
covid_data.describe().T
# Out:
#                                         count unique  top  freq
# Breathing Problem                        5434      2  Yes  3620
# Fever                                    5434      2  Yes  4273
# Dry Cough                                5434      2  Yes  4307
# Sore throat                              5434      2  Yes  3953
# Running Nose                             5434      2  Yes  2952
# Asthma                                   5434      2   No  2920
# Chronic Lung Disease                     5434      2   No  2869
# Headache                                 5434      2  Yes  2736
# Heart Disease                            5434      2   No  2911
# Diabetes                                 5434      2   No  2846
# Hyper Tension                            5434      2   No  2771
# Fatigue                                  5434      2  Yes  2821
# Gastrointestinal                         5434      2   No  2883
# Abroad travel                            5434      2   No  2983
# ...

# %% [markdown]
# El cuadro de datos que has proporcionado parece describir la presencia de diferentes síntomas y factores de riesgo en una muestra de 5434 individuos, en relación con el diagnóstico de COVID-19. Aquí está la interpretación detallada de cada columna:
#
# ### Breathing Problem:
#
# Total: 5434
# Sí: 3620
# No: 1814
# Interpretación: 3620 individuos reportaron tener problemas respiratorios, mientras que 1814 no los tuvieron.
# ### Fever:
#
# Total: 5434
# Sí: 4273
# No: 1161
# Interpretación: La fiebre es un síntoma común con 4273 individuos reportándola.
# ### Dry Cough:
#
# Total: 5434
# Sí: 4307
# No: 1127
# Interpretación: 4307 individuos reportaron tener tos seca.
# ### Sore throat:
#
# Total: 5434
# Sí: 3953
# No: 1481
# Interpretación: 3953 individuos reportaron tener dolor de garganta.
# ### Running Nose:
#
# Total: 5434
# Sí: 2952
# No: 2482
# Interpretación: La nariz congestionada o con secreción fue reportada por 2952 individuos.
# ### Asthma:
#
# Total: 5434
# No: 2920
# Sí: 2514
# Interpretación: 2920 individuos no tenían asma, mientras que 2514 sí lo tenían.
# ### Chronic Lung Disease:
#
# Total: 5434
# No: 2869
# Sí: 2565
# Interpretación: 2869 individuos no tenían enfermedad pulmonar crónica.
# ### Headache:
#
# Total: 5434
# Sí: 2736
# No: 2698
# Interpretación: 2736 individuos reportaron tener dolor de cabeza.
# ### Heart Disease:
#
# Total: 5434
# No: 2911
# Sí: 2523
# Interpretación: 2911 individuos no tenían enfermedades cardíacas.
# ### Diabetes:
#
# Total: 5434
# No: 2846
# Sí: 2588
# Interpretación: 2846 individuos no tenían diabetes.
# ### Hyper Tension:
#
# Total: 5434
# No: 2771
# Sí: 2663
# Interpretación: 2771 individuos no tenían hipertensión.
# ### Fatigue:
#
# Total: 5434
# Sí: 2821
# No: 2613
# Interpretación: 2821 individuos reportaron sentirse fatigados.
# ### Gastrointestinal:
#
# Total: 5434
# No: 2883
# Sí: 2551
# Interpretación: 2883 individuos no tenían problemas gastrointestinales.
# ### Abroad travel:
#
# Total: 5434
# No: 2983
# Sí: 2451
# Interpretación: 2983 individuos no habían viajado al extranjero.
# ### Contact with COVID Patient:
#
# Total: 5434
# Sí: 2726
# No: 2708
# Interpretación: 2726 individuos reportaron haber tenido contacto con un paciente de COVID-19.
# ### Attended Large Gathering:
#
# Total: 5434
# No: 2924
# Sí: 2510
# Interpretación: 2924 individuos no asistieron a grandes reuniones.
# ### Visited Public Exposed Places:
#
# Total: 5434
# Sí: 2820
# No: 2614
# Interpretación: 2820 individuos visitaron lugares públicos expuestos.
# ### Family working in Public Exposed Places:
#
# Total: 5434
# No: 3172
# Sí: 2262
# Interpretación: 3172 individuos no tenían familiares trabajando en lugares públicos expuestos.
# ### Wearing Masks:
#
# Total: 5434
# No: 5434
# Interpretación: Todos los individuos reportaron no usar mascarillas.
# ### Sanitization from Market:
#
# Total: 5434
# No: 5434
# Interpretación: Todos los individuos reportaron no realizar desinfección de productos del mercado.
# ### COVID-19:
#
# Total: 5434
# Sí: 4383
# No: 1051
# Interpretación: 4383 individuos fueron diagnosticados con COVID-19.
#
# ### Conclusión
# Estos datos proporcionan una visión detallada de la prevalencia de síntomas, factores de riesgo y comportamientos relacionados con el COVID-19 en una muestra específica de 5434 individuos. La alta incidencia de síntomas como fiebre, tos seca, y dolor de garganta, así como el contacto con pacientes de COVID-19, son indicativos de la diseminación y características comunes de la enfermedad en esta población.

# %%
covid_data.head()
# Out:
#   Breathing Problem Fever Dry Cough Sore throat Running Nose Asthma  \
# 0               Yes   Yes       Yes         Yes          Yes     No
# 1               Yes   Yes       Yes         Yes           No    Yes
# 2               Yes   Yes       Yes         Yes          Yes    Yes
# 3               Yes   Yes       Yes          No           No    Yes
# 4               Yes   Yes       Yes         Yes          Yes     No
#
#   Chronic Lung Disease Headache Heart Disease Diabetes  ... Fatigue   \
# 0                   No       No            No      Yes  ...      Yes
# 1                  Yes      Yes            No       No  ...      Yes
# 2                  Yes      Yes            No      Yes  ...      Yes
# 3                   No       No           Yes      Yes  ...       No
# 4                  Yes      Yes           Yes      Yes  ...       No
#
#   Gastrointestinal  Abroad travel Contact with COVID Patient  \
# 0               Yes            No                        Yes
# ...

# %%
# create a table with data missing 
missing_values=covid_data.isnull().sum() # missing values

percent_missing = covid_data.isnull().sum()/covid_data.shape[0]*100 # missing value %

value = {
    'missing_values ':missing_values,
    'percent_missing %':percent_missing  
}
frame=pd.DataFrame(value)
frame
# Out:
#                                          missing_values   percent_missing %
# Breathing Problem                                      0                0.0
# Fever                                                  0                0.0
# Dry Cough                                              0                0.0
# Sore throat                                            0                0.0
# Running Nose                                           0                0.0
# Asthma                                                 0                0.0
# Chronic Lung Disease                                   0                0.0
# Headache                                               0                0.0
# Heart Disease                                          0                0.0
# Diabetes                                               0                0.0
# Hyper Tension                                          0                0.0
# ...

# %%
sns.heatmap(covid_data.isnull(),yticklabels=False,cbar=False,cmap='Pastel1')
# Out:
# <AxesSubplot:>

# %% [markdown]
# vemos que no existe ningun valores faltantes

# %%
ax = sns.countplot(x='COVID-19',data=covid_data, palette="PuRd")
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %%
covid_data["COVID-19"].value_counts().plot.pie(explode=[0.1,0.1],autopct='%1.1f%%',shadow=True)
plt.title('Covid Positive');

# %%
ax = sns.countplot(x='Breathing Problem',data=covid_data, palette="Set1")
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %%
ax = sns.countplot(x='Breathing Problem',hue='COVID-19',data=covid_data, palette="Set2")
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %% [markdown]
# ### Problemas Respiratorios y COVID-19:
#
# La gran mayoría de las personas con problemas respiratorios han sido diagnosticadas con COVID-19 (3369 casos).
# Un número mucho menor de personas con problemas respiratorios no tiene COVID-19 (251 casos).
# Sin Problemas Respiratorios y COVID-19:
#
# De aquellos sin problemas respiratorios, 1014 han sido diagnosticados con COVID-19.
# 800 personas sin problemas respiratorios no han sido diagnosticadas con COVID-19.

# %%
ax = sns.countplot(x='Fever',data=covid_data)
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %%
ax = sns.countplot(x='Dry Cough',hue='COVID-19',data=covid_data, palette="Set1")
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %%
ax = sns.countplot(x='Sore throat',hue='COVID-19',data=covid_data, palette="Set2")
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %%
ax = sns.countplot(x='Abroad travel',hue='COVID-19',data=covid_data)
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %%
ax = sns.countplot(x='Contact with COVID Patient',hue='COVID-19',data=covid_data, palette="PuRd")
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %%
ax = sns.countplot(x='Attended Large Gathering',hue='COVID-19',data=covid_data, palette="Set1")
for p in ax.patches:
     ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()+100), ha='center', va='top', color='white', size=10)
plt.show()

# %%
e=LabelEncoder()
covid_data['Breathing Problem']=e.fit_transform(covid_data['Breathing Problem'])
covid_data['Fever']=e.fit_transform(covid_data['Fever'])
covid_data['Dry Cough']=e.fit_transform(covid_data['Dry Cough'])
covid_data['Sore throat']=e.fit_transform(covid_data['Sore throat'])
covid_data['Running Nose']=e.fit_transform(covid_data['Running Nose'])
covid_data['Asthma']=e.fit_transform(covid_data['Asthma'])
covid_data['Chronic Lung Disease']=e.fit_transform(covid_data['Chronic Lung Disease'])
covid_data['Headache']=e.fit_transform(covid_data['Headache'])
covid_data['Heart Disease']=e.fit_transform(covid_data['Heart Disease'])
covid_data['Diabetes']=e.fit_transform(covid_data['Diabetes'])
covid_data['Hyper Tension']=e.fit_transform(covid_data['Hyper Tension'])
covid_data['Abroad travel']=e.fit_transform(covid_data['Abroad travel'])
covid_data['Contact with COVID Patient']=e.fit_transform(covid_data['Contact with COVID Patient'])
covid_data['Attended Large Gathering']=e.fit_transform(covid_data['Attended Large Gathering'])
covid_data['Visited Public Exposed Places']=e.fit_transform(covid_data['Visited Public Exposed Places'])
covid_data['Family working in Public Exposed Places']=e.fit_transform(covid_data['Family working in Public Exposed Places'])
covid_data['Wearing Masks']=e.fit_transform(covid_data['Wearing Masks'])
covid_data['Sanitization from Market']=e.fit_transform(covid_data['Sanitization from Market'])
covid_data['COVID-19']=e.fit_transform(covid_data['COVID-19'])
covid_data['Dry Cough']=e.fit_transform(covid_data['Dry Cough'])
covid_data['Sore throat']=e.fit_transform(covid_data['Sore throat'])
covid_data['Gastrointestinal ']=e.fit_transform(covid_data['Gastrointestinal '])
covid_data['Fatigue ']=e.fit_transform(covid_data['Fatigue '])

# %%
# Crear una instancia de LabelEncoder
e = LabelEncoder()

# Lista de columnas categóricas
categorical_columns = [
    'Breathing Problem', 'Fever', 'Dry Cough', 'Sore throat', 'Running Nose',
    'Asthma', 'Chronic Lung Disease', 'Headache', 'Heart Disease', 'Diabetes',
    'Hyper Tension', 'Abroad travel', 'Contact with COVID Patient',
    'Attended Large Gathering', 'Visited Public Exposed Places',
    'Family working in Public Exposed Places', 'Wearing Masks',
    'Sanitization from Market', 'COVID-19', 'Gastrointestinal ', 'Fatigue '
]

# Aplicar LabelEncoder a cada columna categórica
for col in categorical_columns:
    covid_data[col] = e.fit_transform(covid_data[col])

# Verificar la transformación
covid_data
# Out:
#       Breathing Problem  Fever  Dry Cough  Sore throat  Running Nose  Asthma  \
# 0                     1      1          1            1             1       0
# 1                     1      1          1            1             0       1
# 2                     1      1          1            1             1       1
# 3                     1      1          1            0             0       1
# 4                     1      1          1            1             1       0
# ...                 ...    ...        ...          ...           ...     ...
# 5429                  1      1          0            1             1       1
# 5430                  1      1          1            0             1       1
# 5431                  1      1          1            0             0       0
# 5432                  1      1          1            0             1       0
# 5433                  1      1          1            0             1       1
#
# ...

# %% [markdown]
# Para transformar las variables categóricas en tu conjunto de datos a formato numérico utilizando LabelEncoder. Este proceso es esencial para preparar los datos antes de entrenar modelos de machine learning, ya que la mayoría de los algoritmos de machine learning requieren datos numéricos.

# %%
covid_data.hist(figsize=(20,15));

# %%
print(covid_data['Wearing Masks'].value_counts())
sns.countplot(x='Wearing Masks',data=covid_data)
# Out:
# 0    5434
# Name: Wearing Masks, dtype: int64
# <AxesSubplot:xlabel='Wearing Masks', ylabel='count'>

# %%
print(covid_data['Sanitization from Market'].value_counts())
sns.countplot(x='Sanitization from Market',data=covid_data)
# Out:
# 0    5434
# Name: Sanitization from Market, dtype: int64
# <AxesSubplot:xlabel='Sanitization from Market', ylabel='count'>

# %%
covid_data=covid_data.drop('Wearing Masks',axis=1)
covid_data=covid_data.drop('Sanitization from Market',axis=1)

# %% [markdown]
# Las columnas Wearing Masks y Sanitization from Market se eliminaron porque todos los valores en estas columnas eran No. Esto significa que no hay variabilidad en estos datos y, por lo tanto, no aportan información útil al modelo de machine learning. Cuando una columna tiene un solo valor para todas las filas, no proporciona ninguna capacidad predictiva ni contribuye a la diferenciación entre las clases en el análisis. En este caso, todas las entradas de Wearing Masks y Sanitization from Market eran No, lo que indica que no hay variabilidad en estos datos.

# %%
covid_data.columns
# Out:
# Index(['Breathing Problem', 'Fever', 'Dry Cough', 'Sore throat',
#        'Running Nose', 'Asthma', 'Chronic Lung Disease', 'Headache',
#        'Heart Disease', 'Diabetes', 'Hyper Tension', 'Fatigue ',
#        'Gastrointestinal ', 'Abroad travel', 'Contact with COVID Patient',
#        'Attended Large Gathering', 'Visited Public Exposed Places',
#        'Family working in Public Exposed Places', 'COVID-19'],
#       dtype='object')

# %%
plt.figure(figsize=(25,20))
sns.heatmap(covid_data.corr(), annot=True, cmap="PuRd")
# Out:
# <AxesSubplot:>

# %% [markdown]
# El mapa de calor indica que algunas características específicas, como problemas respiratorios, fiebre, tos seca y dolor de garganta, tienen una correlación moderada con la presencia de COVID-19, lo que puede ser útil para la predicción del diagnóstico de la enfermedad. Sin embargo, es importante considerar todas las características en conjunto para realizar un análisis completo.

# %% [markdown]
# ## MACHINE LEARNING

# %%
x=covid_data.drop('COVID-19',axis=1)
y=covid_data['COVID-19']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 101)

accuracies = {}
algo_time={}
r2_scores={}
mean_squared_errors={}
roc_auc_scores={}

def print_performance2(yt,clf,clf_name):
    y_pred=clf.predict(x_test)
    roc_auc_scores[clf_name]=roc_auc_score(yt,y_pred)*100
    mean_squared_errors[clf_name]=mean_squared_error(yt,y_pred)*100
    r2_scores[clf_name]=r2_score(yt,y_pred)*100
    accuracies[clf_name]=clf.score(x_train,y_train)*100
    print('ROC_AUC value :',roc_auc_scores[clf_name],"%",'\n')
    print("Mean Squared Error :",mean_squared_errors[clf_name],"%")
    print("\nR2 score is :",r2_scores[clf_name],"%")
    print("\nAccuracy Score :",accuracies[clf_name],"%")
    print('\nClassification Report : ','\n',classification_report(yt,y_pred))
    
    confusionmatrix=confusion_matrix(yt,y_pred)

    fig, ax = plt.subplots(figsize=(3, 3))
    ax.matshow(confusionmatrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(confusionmatrix.shape[0]):
        for j in range(confusionmatrix.shape[1]):
            ax.text(x=j, y=i,s=confusionmatrix[i, j], va='center', ha='center', size='xx-large')
 
    plt.xlabel('Predictions', fontsize=18)
    plt.ylabel('Actuals', fontsize=18)
    plt.title('Confusion Matrix', fontsize=18)

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
import time

# Definimos los hiperparámetros que queremos probar
param_grid = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
    'max_iter': [100, 200, 300]
}

# Creamos el modelo de regresión logística
lr = LogisticRegression()

# Configuramos el GridSearchCV
grid_search = GridSearchCV(estimator=lr, param_grid=param_grid, cv=5, scoring='accuracy')

# Medimos el tiempo de ejecución
start = time.time()
grid_search.fit(x_train, y_train)
end = time.time()

# Guardamos el mejor modelo
best_lr = grid_search.best_estimator_

# Imprimimos los resultados
print("LOGISTIC REGRESSION")
print("Mejores hiperparámetros:", grid_search.best_params_)
print("Mejor precisión en validación cruzada:", grid_search.best_score_)

# Evaluamos el rendimiento del mejor modelo en el conjunto de prueba
print_performance2(y_test, best_lr, 'LOGISTIC REGRESSION')

# Guardamos el tiempo de ejecución
algo_time['LOGISTIC REGRESSION'] = end - start
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %% [markdown]
# ### Mejores hiperparámetros: {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
#
# #### C: 0.1 significa que el modelo tiene una regularización más fuerte.
# #### max_iter: 100 es el número de iteraciones máximas para la convergencia.
# #### penalty: 'l1' significa que se usa la regularización Lasso.
# #### solver: 'liblinear' es un solucionador adecuado para conjuntos de datos pequeños.
# #### Mejor precisión en validación cruzada: 0.971 (97.15%)
#
# ### Métricas de rendimiento
# #### ROC_AUC: 93.23%
#
# Esto indica que el modelo es capaz de distinguir entre las clases positivas y negativas el 93.23% del tiempo.
# #### Mean Squared Error (MSE): 3.04%
#
# Un MSE bajo indica que el modelo está prediciendo con alta precisión.
# #### R2 score: 80.09%
#
# El 80.09% de la variabilidad de los datos es explicada por el modelo.
# #### Accuracy Score: 97.03%
#
# El modelo clasifica correctamente el 97.03% de las instancias.
# Informe de clasificación (Classification Report)
# #### Precisión (Precision):
#
# Clase 0: 96%
# Clase 1: 97%
# #### Recuperación (Recall):
#
# Clase 0: 87%
# Clase 1: 99%
# #### F1-score:
#
# Clase 0: 92%
# Clase 1: 98%
# #### Soporte (Support):
#
# Clase 0: 204 instancias
# Clase 1: 883 instancias
# #### Interpretación
# Precisión alta para ambas clases indica que la proporción de verdaderos positivos entre las instancias clasificadas como positivas es alta.
# Recuperación alta para la clase 1 (99%) muestra que casi todos los verdaderos positivos son identificados correctamente por el modelo.
# F1-score alto, especialmente para la clase 1 (98%), indica un buen equilibrio entre precisión y recuperación.
# Accuracy de 97.03% confirma que el modelo es muy preciso en general.
# ROC_AUC de 93.23% sugiere que el modelo es muy bueno discriminando entre las clases positivas y negativas.
#
# ### Matriz de confusión
# Interpretación de la Matriz de Confusión
# No predicho (0) Sí predicho (1)
# #### Verdaderos Negativos (VN): 178
# Casos en los que el modelo predijo correctamente que no había COVID-19.
# #### Falsos Positivos (FP): 26
# Casos en los que el modelo predijo que había COVID-19 cuando en realidad no lo había.
# #### Falsos Negativos (FN): 11
# Casos en los que el modelo predijo que no había COVID-19 cuando en realidad sí había.
# #### Verdaderos Positivos (VP): 876
# Casos en los que el modelo predijo correctamente que había COVID-19.

# %% [markdown]
# ## RANDOM FOREST

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, mean_squared_error, r2_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import time

# Definimos los hiperparámetros que queremos probar
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [10, 20, 30],
    'criterion': ['gini', 'entropy']
}


# Creamos el modelo de Random Forest
rf = RandomForestClassifier()

# Configuramos el GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=5, scoring='accuracy')

# Medimos el tiempo de ejecución
start = time.time()
grid_search.fit(x_train, y_train)
end = time.time()

# Guardamos el mejor modelo
best_rf = grid_search.best_estimator_

# Inicializamos los diccionarios para almacenar métricas
accuracies = {}
algo_time = {}
r2_scores = {}
mean_squared_errors = {}
roc_auc_scores = {}


# Imprimimos los resultados
print("RANDOM FOREST")
print("Mejores hiperparámetros:", grid_search.best_params_)
print("Mejor precisión en validación cruzada:", grid_search.best_score_)

# Evaluamos el rendimiento del mejor modelo en el conjunto de prueba
print_performance2(y_test, best_rf, 'RANDOM FOREST')

# Guardamos el tiempo de ejecución
algo_time['RANDOM FOREST'] = end - start
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 90 fits failed out of a total of 270.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Usuario\anaconda3\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %% [markdown]
# ### Mejores Hiperparámetros Encontrados
# criterion: 'gini'
# max_depth: 20
# max_features: 'sqrt'
# n_estimators: 100
# Estos hiperparámetros fueron seleccionados a través de GridSearchCV como los que proporcionan el mejor rendimiento para el modelo.
#
# ### Rendimiento del Modelo en Validación Cruzada
# ### Mejor precisión en validación cruzada: 0.9837 (o 98.37%)
# ### Métricas de Evaluación en el Conjunto de Prueba
# ### ROC AUC:
#
# Valor: 97.15%
# Explicación: El área bajo la curva ROC (Receiver Operating Characteristic) mide la capacidad del modelo para distinguir entre clases. Un valor más cercano a 100% indica un excelente rendimiento.
#
# ### Mean Squared Error (MSE):
#
# Valor: 2.48%
# Explicación: El error cuadrático medio mide la media de los cuadrados de los errores, es decir, la diferencia promedio entre los valores predichos y los valores reales. Un valor más bajo indica mejores predicciones.
#
# ### R2 Score:
#
# Valor: 83.71%
# Explicación: El coeficiente de determinación (R2) indica qué tan bien las predicciones del modelo se ajustan a los datos reales. Un valor más cercano a 100% es mejor.
#
# ### Accuracy Score:
#
# Valor: 98.46%
#
# Explicación: La precisión del modelo indica el porcentaje de predicciones correctas sobre el total de casos.
# Informe de Clasificación (Classification Report)
# Precision, Recall y F1-Score:
# Clase 0 (sin COVID-19):
# #### Precision: 0.91
# #### Recall: 0.97
# #### F1-Score: 0.94
# #### Soporte: 204 (cantidad de ejemplos de esta clase en el conjunto de prueba)
# Clase 1 (con COVID-19):
# #### Precision: 0.99
# #### Recall: 0.98
# #### F1-Score: 0.98
# #### Soporte: 883 (cantidad de ejemplos de esta clase en el conjunto de prueba)
# #### Accuracy: 0.98 (precisión total del modelo)
# #### Macro avg: Promedio de las métricas para cada clase.
# #### Weighted avg: Promedio ponderado de las métricas para cada clase, teniendo en cuenta el soporte de cada clase.
# ### Interpretación de los Resultados
# #### ROC AUC: El modelo de Random Forest tiene un excelente rendimiento en la discriminación entre las clases con un ROC AUC de 97.15%.
# #### MSE: El error cuadrático medio es bajo (2.48%), indicando que las predicciones del modelo están cerca de los valores reales.
# #### R2 Score: Un R2 de 83.71% sugiere que el modelo explica una gran parte de la variabilidad en los datos.
# #### Accuracy: La precisión de 98.46% indica que el modelo predice correctamente la gran mayoría de los casos.
# #### Precision, Recall y F1-Score: Los valores altos de precisión, recall y F1-score, especialmente para la clase positiva (con COVID-19), muestran que el modelo es muy efectivo en la identificación de casos de COVID-19.
#
# ### Interpretación de la Matriz de Confusión
# ### Verdaderos Negativos (VN): 197
# Casos en los que el modelo predijo correctamente que no había COVID-19.
#
# ### Falsos Positivos (FP): 20
# Casos en los que el modelo predijo que había COVID-19 cuando en realidad no lo había.
# ### Falsos Negativos (FN): 7
# Casos en los que el modelo predijo que no había COVID-19 cuando en realidad sí había.
# ### Verdaderos Positivos (VP): 863
# Casos en los que el modelo predijo correctamente que había COVID-19.

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# El modelo de Random Forest muestra un rendimiento superior en la mayoría de las métricas clave comparado con el modelo de Regresión Logística:
#
# ### Mejor precisión en validación cruzada: 98.37% frente a 97.15%
# ### ROC AUC: 97.15% frente a 93.23%
# ### MSE: 2.48% frente a 3.04%
# ### R2 score: 83.71% frente a 80.09%
# ### Accuracy: 98.46% frente a 97.03%
# ### Recall (Clase 0): 97% frente a 87%
# ### F1-score (Clase 0): 94% frente a 92%
# En particular, la mayor precisión en validación cruzada, el mayor ROC AUC, y la menor MSE sugieren que el modelo de Random Forest es más preciso y mejor para distinguir entre clases.

# %% [markdown]
# ## INTEFRAZ DE USUARIO USANDO RANDOM FOREST

# %% [markdown]
# #### Esta investigación puede servir como una herramienta de apoyo para la toma de decisiones médicas, ya que el modelo desarrollado facilita la identificación de la presencia de COVID-19 en función de los síntomas de una persona. También puede ser útil para individuos con síntomas relacionados con COVID-19, quienes podrán usarla para evaluar la probabilidad de obtener un resultado positivo o negativo en una prueba de COVID-19. El modelo creado tiene el potencial de ser integrado en una aplicación con las siguientes características:

# %%
import colorama
from colorama import Fore

# Inicializa colorama
colorama.init(autoreset=True)

print("PREDICCIÓN DE COVID BASADO EN ALGORITMOS DE ML")
print("Ingrese 1 para Sí y 0 para No")

# Preguntas en español
Breathing_Problem = int(input("¿Tiene el paciente problemas para respirar? "))
Fever = int(input("¿Tiene el paciente fiebre? "))
Dry_Cough = int(input("¿Tiene el paciente tos seca? "))
Sore_throat = int(input("¿Tiene el paciente dolor de garganta? "))
Running_Nose = int(input("¿Tiene el paciente secreción nasal? "))
Asthma = int(input("¿Tiene el paciente algún historial de asma? "))
Chronic_Lung_Disease = int(input("¿Tiene el paciente alguna enfermedad pulmonar crónica? "))
Headache = int(input("¿Tiene el paciente dolor de cabeza? "))
Heart_Disease = int(input("¿Tiene el paciente alguna enfermedad cardíaca? "))
Diabetes = int(input("¿Tiene el paciente diabetes? "))
Hyper_Tension = int(input("¿Tiene el paciente hipertensión? "))
Fatigue = int(input("¿Tiene el paciente fatiga? "))
Gastrointestinal = int(input("¿Tiene el paciente algún trastorno gastrointestinal? "))
Abroad_travel = int(input("¿Ha viajado el paciente al extranjero recientemente? "))
Contact_with_COVID_Patient = int(input("¿Ha estado el paciente en contacto con un paciente de COVID recientemente? "))
Attended_Large_Gathering = int(input("¿Ha asistido el paciente a algún evento con gran cantidad de personas recientemente? "))
Visited_Public_Exposed_Places = int(input("¿Ha visitado el paciente lugares públicos expuestos recientemente? "))
Family_working_in_Public_Exposed_Places = int(input("¿Tiene el paciente algún familiar que trabaje en lugares públicos expuestos? "))

# Recolectar las respuestas del paciente en una lista
patient = [[Breathing_Problem, Fever, Dry_Cough, Sore_throat, Running_Nose, Asthma, Chronic_Lung_Disease, Headache, Heart_Disease, Diabetes, Hyper_Tension, Fatigue, Gastrointestinal, Abroad_travel, Contact_with_COVID_Patient, Attended_Large_Gathering, Visited_Public_Exposed_Places, Family_working_in_Public_Exposed_Places]]

# Realizar la predicción usando el modelo Random Forest
result = best_rf.predict(patient)
print("\nResultados: ", result)

# Mostrar el resultado con mensajes en español y colores
if result == 1:
    print(Fore.RED + '¡Podría estar afectado por el virus COVID-19! ¡Por favor, hágase una prueba RTPCR lo antes posible y permanezca en cuarentena durante 14 días!')
    print()
else:
    print(Fore.GREEN + 'No tiene síntomas de COVID-19. ¡Quédese en casa! ¡Manténgase seguro!')
    print()
# Out:
# PREDICCIÓN DE COVID BASADO EN ALGORITMOS DE ML
# Ingrese 1 para Sí y 0 para No
# ¿Tiene el paciente problemas para respirar? 1
# ¿Tiene el paciente fiebre? 1
# ¿Tiene el paciente tos seca? 1
# ¿Tiene el paciente dolor de garganta? 1
# ¿Tiene el paciente secreción nasal? 1
# ¿Tiene el paciente algún historial de asma? 1
# ¿Tiene el paciente alguna enfermedad pulmonar crónica? 0
# ¿Tiene el paciente dolor de cabeza? 0
# ¿Tiene el paciente alguna enfermedad cardíaca? 0
# ¿Tiene el paciente diabetes? 0
# ¿Tiene el paciente hipertensión? 0
# ¿Tiene el paciente fatiga? 1
# ¿Tiene el paciente algún trastorno gastrointestinal? 1
# ¿Ha viajado el paciente al extranjero recientemente? 1
# ¿Ha estado el paciente en contacto con un paciente de COVID recientemente? 1
# ¿Ha asistido el paciente a algún evento con gran cantidad de personas recientemente? 1
# ¿Ha visitado el paciente lugares públicos expuestos recientemente? 1
# ...
